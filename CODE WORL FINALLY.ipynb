# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df=pd.read_csv(r'C:\Users\USER\PJ1\CoffeeAndCode.csv')

# %%
df = df.dropna(how='any',axis=0)

# %%
def get_avarage(df,column):
    """
    Description: This function to return the average value of the column 
    """
    return sum(df[column])/len(df)

# %%
def get_avarge_between_two_columns(df,column1,column2):
   
    
    List=list(df[column1].unique())
    average=[]

    for i in List:
        x=df[df[column1]==i]
        column1_average= get_avarage(x,column2)
        average.append(column1_average)

  
    df_column1_column2=pd.DataFrame({'column1':List,'column2':average})

    return df_column1_column2

# %%
def plot(data,xlabel,ylabel):
    """
    Description: This function to draw a barplot
    """
        
    plt.figure(figsize=(15,5))
    ax=sns.barplot(x=data.column1,y=data.column2,palette='rocket')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
data4 = get_avarge_between_two_columns(df,'CoffeeType','CoffeeCupsPerDay')
plot(data4,'type','cups')

# %%
data1 = get_avarge_between_two_columns(df,'CoffeeSolveBugs','CoffeeCupsPerDay')
plot(data1,'type','cups')

# %%
data1 = get_avarge_between_two_columns(df,'CoffeeTime','CoffeeCupsPerDay')
plot(data1,'type','cups')
